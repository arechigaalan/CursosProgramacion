# %%
import pandas as pd

# %%
datos = {
    'nombre': ['Pedro', 'Juan', 'Lorena'],
    'edad': [25, 39, 33] 
}

# %%
df = pd.DataFrame(datos)
df
# Out:
#    nombre  edad
# 0   Pedro    25
# 1    Juan    39
# 2  Lorena    33

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df['nombre'] #! Obtener la serie 'nombre' del dataframe 'df'
# Out:
# 0     Pedro
# 1      Juan
# 2    Lorena
# Name: nombre, dtype: str

# %%
df.nombre #! Otra forma de extraer la serie de un dataframe
# Out:
# 0     Pedro
# 1      Juan
# 2    Lorena
# Name: nombre, dtype: str

# %%
import pandas as pd

datos_empleados = {
    'nombre': ['Ana', 'Luis', 'Carlos'],
    'edad': [30, 25, 40]
}

df_empleados = pd.DataFrame(datos_empleados)
shape_df = df_empleados.shape #! Obtener el mataño del dataframe.
columns_df = df_empleados.columns #! Obtener las columnas del dataframe.
index_df = df_empleados.index #! Obtener los índices del dataframe.
shape_df, columns_df, index_df
# Out:
# ((3, 2),
#  Index(['nombre', 'edad'], dtype='str'),
#  RangeIndex(start=0, stop=3, step=1))
